# %% [markdown]
# # Тема 4. Исследовательский анализ данных на Python

# %% [markdown]
# ## Описательная статистика. Библиотеки stats, scipy
#
# Тьюки Д. Анализ результатов наблюдений. Разведочный метод. -- М.: Мир, 1981. -- 694 с.
#
# Mukhiya S., Ahmed U. Hands-On Exploratory Data Analysis with Python: Perform EDA techniques to understand, summarize, and investigate your data. - Packt Publishing. - 2020 p.
#
# [Разведочный анализ данных](https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D0%B7%D0%B2%D0%B5%D0%B4%D0%BE%D1%87%D0%BD%D1%8B%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85) (англ. exploratory data analysis, EDA) -- анализ основных свойств данных, нахождение в них общих закономерностей, распределений и аномалий, построение начальных моделей, зачастую с использованием инструментов визуализации.
#
# Понятие введено математиком Джоном Тьюки, который сформулировал цели такого анализа следующим образом:
# - максимальное «проникновение» в данные;
# - выявление основных структур;
# - выбор наиболее важных переменных;
# - обнаружение отклонений и аномалий;
# - проверка основных гипотез;
# - разработка начальных моделей.
#
# Числовые данные - данные, которые выражаются на числовой шкале.
# - Непрерывные данные, которые могут принимать любое значение в интервале.
# - Дискретные данные, которые могут принимать только целочисленные значения, такие как количества.
#
# Категориальные данные - данные, которые могут принимать только конкретное множество значений, представляющих множество возможных категорий.
#  - Двоичные данные - частный случай категориальных данных с двумя категориями значений, например, 0/1, истина/ложь.
#  - Порядковые данные - категориальные данные, которые имеют явно заданное упорядочение.
#
# Выборка или выборочная совокупность -- часть генеральной совокупности элементов, которая охватывается экспериментом (наблюдением, опросом).
#
# Базовый шаг в разведывании данных состоит в получении <<типичного значения>> для каждого признака (переменной): оценки того, где расположено большинство данных, т.е. их центральной тенденции.
#
# Оценки центрального положения:
# - выборочное среднее -- сумма всех значений, деленная на число значений:
# $$
# \bar{x} = \dfrac{1}{n}\sum\limits_{i=1}^{n}x_i,
# $$
# где $x_i$ -- наблюдаемые (выборочные) значения случайной величины $X$;
#
# - медиана -- значение, для которого половина сортированных данных находится выше и ниже данного значения;
# - мода — это значение, которое встречается наиболее часто в наборе данных. Мода как средняя величина употребляется чаще для категориальных данных.
#
# Центральное положение — это всего одна из размерностей в обобщении признака.
# Вторая размерность, вариабельность, именуемая также дисперсностью, показывает,
# сгруппированы ли значения данных плотно, или же они разбросаны.
#
# Оценки вариабельности:
# - дисперсия -- сумма квадратичных отклонений от среднего, деленная на $n$, где $n$ — это число значений данных:
# $$
# \bar{s}^2 = \dfrac{1}{n}\sum\limits_{i=1}^{n}(x_i-\bar{x})^2;
# $$
# - стандартное отклонение -- квадратный корень из дисперсии:
# $$s=\sqrt{s^2};$$
# - размах — это разность между максимальным и минимальным значениями переменной в наборе данных;
# - процентиль -- такое значение, что $P$ процент значений принимает данное значение или меньшее и $(100 - P)$ процент значений принимает данное значение или большее.

# %% [markdown]
# ## Взаимосвязь данных
#
# [Корреляция или корреляционная зависимость](https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D1%8F) — статистическая взаимосвязь двух или более случайных величин, при этом изменения значений одной или нескольких из этих величин сопутствуют систематическому изменению значений другой или других величин.
#
# Коэффициент корреляции характеризует степень зависимости этих величин, причем не любой зависимости, а только линейной, проявляющейся в том, что при возрастании одной случайной величины другая проявляет тенденцию также возрастать (или убывать). В первом случае $ r_{xy}>0 $, и говорят, что случайные величины $X$ и $Y$ связаны положительной корреляцией, во втором $ r_{xy}<0 $, и корреляция отрицательна.
#
# Для любых двух случайных величин $X$, $Y$
# $$-1\leqslant r_{xy} \leqslant 1.$$
#
# Метод вычисления коэффициента корреляции зависит от вида шкалы, к которой относятся переменные. Так, для измерения переменных с интервальной и количественной шкалами необходимо использовать коэффициент корреляции Пирсона. Если по меньшей мере одна из двух переменных имеет порядковую шкалу, либо не является нормально распределённой, необходимо использовать ранговую корреляцию Спирмена или Кендалла. В случае, когда одна из двух переменных является дихотомической, используется точечная двухрядная корреляция, а если обе переменные являются дихотомическими — четырехполевая корреляция.
#
# Корреляционная матрица -- таблица, в которой строки и столбцы — это переменные, а значения ячеек — корреляции между этими переменными.

# %% [markdown]
# ## Методы визуализации
#
# Коробчатая диаграмма (синоним: ящик с усами) -- график, введенный в употребление в качестве быстрого способа визуализации распределения данных.
#
# Частотная таблица -- сводка количеств числовых значений, которые разбиты на серию частотных интервалов (корзин, бинов).
#
# Гистограмма -- график частотной таблицы, в котором корзины откладываются на оси $x$, а количество (или доля) — на оси $y$.
#
# График плотности -- сглаженная версия гистограммы, часто на основе ядерной оценки плотности.
#
# Диаграмма рассеяния -- график, в котором по оси $x$ откладываются значения одной переменной, а по оси $y$ - значения другой.
#
# Столбиковые диаграммы -- частота или доля каждой категории, изображаемая в виде столбиков.
#
# Круговые диаграммы -- частота или доля каждой категории, изображаемая в виде сектора круга.

# %% [markdown]
# ### Обзор инструментов визуализации данных
#
# Визуализация данных — это представление данных в виде, который обеспечивает наиболее эффективную работу человека по их изучению.
#
# Цели визуализации на разных этапах анализа данных
#
# |Этап|Задачи|
# |--:|:--|
# |Понимание данных|Разработка стратегии предобработки данных|
# |Подготовка данных|Визуализация резульатов предобработки|
# |Моделирование|Проверка корректности моделей|
# |Оценка|Оценка достоверности результатов моделирования|
#
# Группы методов визуализации
# - табличные и графические;
# - одномерные и многомерные;
# - специализированные.
#
# Дашборд (панель индикаторов) -- инструмент для визуализации и анализа информации о бизнес-процессах и их эффективности. Данные, выводимые на панель индикаторов, обычно представлены в виде ключевых показателей эффективности.
#
# Инструменты визуализации:
# 1. Библиотеки `Python`: `Matplotlib`, `Seaborn`, `Plotly` и `dash`;
# 2. Системы бизнес-анатилитики: [`Tableau`](https://public.tableau.com/views/dash1_16226500525220/Dashboard1?:language=en-US&:display_count=n&:origin=viz_share_link).
#
# [Рекомендации по визуализации](https://www.uprock.ru/articles/20-idey-effektivnoy-vizualizacii-dannyh):
# 1. Выберите подходящее средство визуализации;
# 2. Корректно отражайте данные и внешний вид графиков;
# 3. Учитывайте временные промежутки в линейных диаграммах;
# 4. Не стоит делать диаграммы <<сглаженными>>;
# 5. Избегайте запутанных графиков с двойными осями;
# 6. Ограничьте количество секторов в круговой диаграмме;
# 7. Добавьте подписи прямо в график;
# 8. Избегайте хаотичности;
# 9. Пусть данные говорят сами за себя;
# 10. Выберите цветовую палитру, которая соответствует характеру данных;
# 11. Сделайте подписи разборчивыми;
# 12. Вместо того, чтобы поворачивать подписи, используйте линейчатую диаграмму;
# 13. Не ограничивайтесь статической информацией.
#
#
#
#
# Ресурсы:
# 1. [36 лучших инструментов для визуализации данных](https://telegra.ph/36-luchshih-instrumentov-dlya-vizualizacii-dannyh-07-19)

# %% [markdown]
# ## Тема 4.2 Построение графиков на Python. Библиотеки matplotlib, seaborn, plotly

# %% [markdown]
# ### [Библиотека `matplotlib`](https://matplotlib.org/)
#
# Библиотека `matplotlib` - это библиотека графики для языка программирования `python`, с помощью которой можно создавать высококачественные рисунки различных форматов.
#
# Главной единицей (объектом самого высокого уровня) при работе с `matplotlib` является рисунок (`Figure`). Любой рисунок в `matplotlib` имеет вложенную структуру. Пользовательская работа подразумевает операции с разными элементами этой структуры:
#
# Figure(Рисунок) -> Axes(Область рисования) -> Axis(Координатная ось)
#
# Рисунок (Figure). Рисунок является объектом самого верхнего уровня, на котором располагаются одна или несколько областей рисования (Axes), элементы рисунка Artisits (заголовки, легенда и т.д.) и основа-холст (Canvas). На рисунке может быть несколько областей рисования Axes, но данная область рисования Axes может принадлежать только одному рисунку Figure.
#
# Область рисования (Axes). Область рисования является объектом среднего уровня, который является, наверное, главным объектом работы с графикой matplotlib в объектно-ориентированом стиле. Это то, что ассоциируется со словом "plot", это часть изображения с пространством данных. Каждая область рисования Axes содержит две (или три в случае трёхмерных данных) координатных оси (Axis объектов), которые упорядочивают отображение данных.
#
# Координатная ось (Axis). Координатная ось являются объектом среднего уровня, которые определяют область изменения данных, на них наносятся деления ticks и подписи к делениям ticklabels. Расположение делений определяется объектом Locator, а подписи делений обрабатывает объект Formatter. Конфигурация координатных осей заключается в комбинировании различных свойств объектов Locator и Formatter.
#
# Рисунки в `matplotlib` создаются путем последовательного вызова команд. Графические элементы (точки, линии, фигуры и т.д.) наслаиваются одна на другую последовательно. При этом последующие перекрывают предыдущие, если они занимают общее участки на рисунке (регулируется параметром zorder).
#
# В `matplotlib` работает правило <<текущей области>>, которое означает, что все графические элементы наносятся на текущую область рисования. Несмотря на то, что областей рисования может быть несколько, одно из них всегда является текущей.
#
# `Matplotlib` cостоит из множества модулей. Модули наполнены различными классами и функциями, которые иерархически связаны между собой.
#
# Модуль `pyplot` предоставляет готовые решения и возможности по настройке базовых параметров рисунка.
#
# Для подключения модуля `pyplot` используется <<стандартная>> команда.
#
# При желании можно задать [стиль оформления рисунка](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use('tableau-colorblind10')

# %% [markdown]
# Создать рисунок `figure` позволяет метод `.figure()`. После вызова любой графической команды, то есть функции, которая создает какой-либо графический объект, например, `plt.scatter()` или `plt.plot()`, всегда существует хотя бы одна область для рисования (по умолчанию прямоугольной формы).
#
# Атрибуты `figure` можно изменить во время создания экземпляра:
# - `figsize` : кортеж из целых или действительных чисел, который определяет ширину и высоту в дюймах;
# - `dpi` : разрешение рисунка;
# - `facecolor` : цвет фона;
# - `edgecolor` : цвет границы.
#
# Результат рисования, то есть текущее состояние рисунка, отображается на экране с помощью команды `plt.show()`. Будут показаны все рисунки (figures), которые были созданы.

# %%
fig = plt.figure(
    figsize=(12,8),
    facecolor='teal',
    edgecolor = 'red')
plt.plot()
plt.show()

# %% [markdown]
# Далее может быть установлена система координат (по умолчанию прямоугольная).

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1], polar=True)
plt.show()

# %% [markdown]
# Для сохранения получившегося рисунок нужно воспользоваться методом `plt.savefig()`. Он сохраняет текущую конфигурацию рисунка в графический файл с некоторым расширением (png, jpeg, pdf и др.), который можно задать через параметр `fmt`.

# %%
fig.savefig('2.jpeg',
             dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-97a47ca292db> in <module>
# ----> 1 fig1.savefig('2.jpeg',
#       2              dpi = 300)
#
# NameError: name 'fig1' is not defined

# %% [markdown]
# Графические команды - это функции, которые, принимая некоторые параметры, возвращают какой-то графический результат. Это может быть текст, линия, график, диаграмма и др. Перечислим наиболее распространенные из них.
#
# В Matplotlib заложены как простые графические команды, так и достаточно сложные. Доступ к ним через pyplot означает использование синтаксиса вида `plt.название_команды()`.
#
# Простые графические команды:
# - `plt.scatter()` - маркер или точечное рисование;
# - `plt.plot()` - ломаная линия;
# - `plt.text()` - нанесение текста;
#
# Диаграммы:
# - plt.bar(), plt.barh(), plt.barbs(), broken_barh() - столбчатая диаграмма;
# - plt.hist(), plt.hist2d(), plt.hlines - гистограмма;
# - plt.pie() - круговая диаграмма;
# - plt.boxplot() - ящик с усами.
#
# Полный список команд можно посмотреть [здесь](https://matplotlib.org/stable/api/pyplot_summary.html).
#
# Доступна настройка вида графиков: цвет, форму, тип линии или маркера, толщина линий, степень прозрачности элементов, размер и тип шрифта и т.д.:
#
# - `color/colors/c` - цвет;
# - `linewidth/linewidths` - толщина линии;
# - `linestyle` - тип линии;
# - `alpha` - степень прозрачности (от полностью прозрачного 0 до непрозрачного 1);
# - `fontsize` - размер шрифта;
# - `marker` - тип маркера;
# - `s` - размер маркера в методе plt.scatter(только цифры);
# - `rotation` - поворот строки на X градусов.
#
# Помимо метода `text()` существуют и другие методы отображения текста в `pyplot`. Ниже представлен список текстовых команд в `pyplot`:
#
# - `plt.xlabel()` - добавляет подпись оси абсции OX;
# - `plt.ylabel()` - добавляет подпись оси ординат OY;
# - `plt.title()` - добавляет заголовок для области рисования Axes;
# - `plt.figtext()` - добавляет текст на рисунок Figure;
# - `plt.suptitle()` - добавляет заголовок для рисунка Figure;
# - `plt.annotate()` - добавляет примечание, которое состоит из текста и необязательной стрелки в указанную область на рисунке;
# - `plt.legend()` - легенда.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('bank_dataset.csv')
df.head(2)
# Out:
#      userid  score       City Gender  Age  Objects   Balance  Products  \
# 0  15677338    619  Ярославль      Ж   42        2       NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1  83807.86         1
#
#    CreditCard  Loyalty  estimated_salary  Churn
# 0           1        1         101348.88      1
# 1           0        1         112542.58      0

# %%
#Шаг с преобработкой пропукаем
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userid            10000 non-null  int64
#  1   score             10000 non-null  int64
#  2   city              10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   objects           10000 non-null  int64
#  6   balance           6383 non-null   float64
#  7   products          10000 non-null  int64
#  8   creditcard        10000 non-null  int64
#  9   loyalty           10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.columns = df.columns.str.lower()

# %%
#стастистики
print(df.objects.mean()) #выборочное среднее
print(df.objects.median()) #медиана
print(df.objects.mode()) #мода
print(df.age.var()) #дисперсия
print(df.age.std()) #среднеквадратичное отклонение
# Out:
# 0    2
# Name: objects, dtype: int64

# %%
fig = plt.figure(figsize=(3,3))
plt.scatter(df.age, df.balance)
plt.show()

# %%
sns.scatterplot(data=df,
                y='balance',
                x='age')
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %%
import math

# %%
list_x = np.arange(-10, 10, 0.1)
list_y = list(map(math.sin, list_x))

# %%
plt.plot(list_x, list_y,
         color='red',
         linewidth=2,
         linestyle='--')

# color/colors/c - цвет;
# linewidth/linewidths - толщина линии;
# linestyle - тип линии;
# alpha - степень прозрачности (от полностью прозрачного 0 до непрозрачного 1);
# fontsize - размер шрифта;
# marker - тип маркера;
# s - размер маркера в методе plt.scatter(только цифры);
# rotation - поворот строки на X градусов.

# %%
plt.plot(df.age, df.balance)

# %%
df.columns
# Out:
# Index(['userid', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'creditcard', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
cols_cont = ['score', 'age', 'balance', 'estimated_salary']
cols_dist = ['city', 'gender', 'objects', 'products', 'creditcard', 'loyalty', 'churn']

# %%
sns.pairplot(df[cols_cont])

# %%
sns.histplot(data=df,
             x='age',
             bins=14)

# sns.histplot(data=df,
#              x='age',
#              bins=50)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
1+3.322*math.log10(10000)
# Out:
# 14.288

# %%
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_new = pd.read_csv('/content/insurance.csv')
sns.pairplot(df_new)

# %%
# Простые графические команды:

# plt.scatter() - маркер или точечное рисование;
# plt.plot() - ломаная линия;
# plt.text() - нанесение текста;
# Диаграммы:

# plt.bar(), plt.barh(), plt.barbs(), broken_barh() - столбчатая диаграмма;
# plt.hist(), plt.hist2d(), plt.hlines - гистограмма;
# plt.pie() - круговая диаграмма;
# plt.boxplot() - ящик с усами.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
x = np.random.randn(10)
y = np.random.randn(10)
colors = np.random.randn(100)
sizes = 1000 * np.random.randn(100)
plt.scatter(x, y,
            #c=colors,
            #s=sizes,
            alpha=0.3,
            cmap='viridis')
plt.annotate('Текст', xy=(-1, 0.5), xytext=(0, 2),
            arrowprops=dict(facecolor='black'))
# for i in np.arange(len(x)):
#     plt.annotate('({:.2f},{:.2f})'.format(x[i], y[i]), (x[i], y[i]), fontsize = 10)
plt.show()
# Out:
# <ipython-input-13-b1fdaca5a8ec>:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,

# %%
n = np.arange(100)
[x1, y1] = [n*np.cos(n), n*np.sin(n)]
[x2, y2] = [n*np.sin(n), n*np.cos(n)]
fig = plt.figure()
plt.plot(x1,y1,
          linestyle = 'dashed',
          marker = 'o',
         color = 'red',
          label = 'Интересный график'
         )
# plt.plot(x2,y2,
#          marker = 'o',
#          label = 'Менее интересный график')
plt.xlabel('Текст для оси абцисс')
plt.ylabel('Текст для оси ординат')
plt.title('Заголовок ' + r'$ \int_{-\infty}^{+\infty}\sin(x) dx$')
plt.legend( )
plt.show();

# %%
n = np.arange(100)
fig = plt.figure()
plt.text(0.2,0.5, 'Какой-то текст')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
z = np.random.random(100)
z1 = [10, 17, 24, 16, 22]
z2 = [12, 14, 21, 13, 17]

# столбчатая диаграмма -- bar()
fig = plt.figure()
plt.bar(x, z1)

# гистограмма -- hist()
fig = plt.figure()
plt.hist(z)

# круговая диаграмма -- pie()
fig = plt.figure()
plt.pie(x)

# ящик с усами -- boxplot()
fig = plt.figure()
plt.boxplot([z1, z2])

plt.show()

# %% [markdown]
# Несколько графиков на одном

# %%
n = np.arange(100)
[x1, y1] = [n*np.cos(n), n*np.sin(n)]
[x2, y2] = [n*np.sin(n), n*np.cos(n)]
fig = plt.figure(figsize = (12,8))
plt.subplot(121)
plt.plot(x1,y1,
         linestyle = 'dashed',
         marker = 'v',
         label = 'Интересный график')
plt.xlabel('Текст для оси абцисс')
plt.ylabel('Текст для оси ординат')
plt.title('Заголовок ' + r'$ \int_{-\infty}^{+\infty}\sin(x) dx$')
plt.legend()

plt.subplot(122)
plt.plot(x2,y2,
         marker = 'o',
         label = 'Менее интересный график')
plt.xlabel('Текст для оси абцисс')
plt.ylabel('Текст для оси ординат')
plt.title('Заголовок ' + r'$ \int_{-\infty}^{+\infty}\sin(x) dx$')
plt.legend()
plt.show()

# %%
n = np.arange(100)
[x1, y1] = [n*np.cos(n), n*np.sin(n)]
[x2, y2] = [n*np.sin(n), n*np.cos(n)]
fig, axs = plt.subplots(1, 2, figsize = (12,8))
axs[0].plot(x1,y1,
                linestyle = 'dashed',
                marker = 'v',
                label = 'Интересный график'
)
axs[0].set(xlabel ='X-Axis',
              ylabel ='Y-Axis',
              xlim =(-200, 200),
              ylim =(-200, 200),
              title ='Заголовок')
axs[0].legend()

axs[1].plot(x2,y2,
         marker = 'o',
         label = 'Менее интересный график')
axs[1].set_xlabel('Текст для оси абцисс')
axs[1].set_ylabel('Текст для оси ординат')
axs[1].set_title('Заголовок ' + r'$ \int_{-\infty}^{+\infty}\sin(x) dx$')
axs[1].legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.1)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
xticks = ax.get_xticks()
yticks = ax.get_yticks()
print('Xticks:', xticks)
print('Yticks:', yticks)

ax.set_xticks([-12.5, 0,  12.5])
ax.set_yticks([-1.25, 0, 1.25])
ax.set_xticklabels([-12.5, 0,  12.5], color='green')
ax.set_yticklabels([-1.25, 0, 1.25], color='green')
plt.show()
# Out:
# Xticks: [-12.5 -10.   -7.5  -5.   -2.5   0.    2.5   5.    7.5  10.   12.5]
# Yticks: [-1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75  1.    1.25]

# %% [markdown]
# ### [Библиотека `seaborn`](https://seaborn.pydata.org/)
#
# Библиотека `seaborn` предоставляет инструменты для работы с цветовым оформлением, настройки стилей, сетки и осей графиков, компоновки графиков, работы с легендой и шрифтами. Особенностью `seaborn` является то, что графики и диаграммы, которые с помощью неё можно построить, имеют красивый внешний вид.
#
#
# Обобенность: удобная работа с категориальными признаками

# %%
df = pd.read_csv('bank_dataset.csv')
df.head(2)
# Out:
#      userid  score       City Gender  Age  Objects   Balance  Products  \
# 0  15677338    619  Ярославль      Ж   42        2       NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1  83807.86         1
#
#    CreditCard  Loyalty  estimated_salary  Churn
# 0           1        1         101348.88      1
# 1           0        1         112542.58      0

# %%
df.columns = df.columns.str.lower()
df.rename(columns={'userid': 'user_id', 'creditcard': 'credit_card'}, inplace = True)

# %%
dict_to_rus = {
'user_id':'идентификатор пользователя',
'score':'баллы кредитного скоринга',
'city': 'город',
'gender': 'пол',
'age': 'возраст',
'objects': 'объекты собственности',
'balance': 'баланс на счете',
'products': 'количество продуктов',
'credit_card': 'наличие кредитной карты',
'loyalty': 'активный клиент',
'estimated_salary': 'заработная плата',
'churn':'уход'
}

# %%
cols_cont
for col in cols_cont:
    sns.histplot(df[col])
    plt.show()

# %%
df.columns
# Out:
# Index(['userid', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'creditcard', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
dict_to = {'city': 'город',
           'loyalty': 'лояность',
           'gender': 'пол',
           'churn': 'уход',
           'objects': 'объекты',
           'products': 'количество продуктов',
           'creditcard': 'наличие кредитной карты'
        }

# %%
cols_dist = ['city', 'gender', 'loyalty', 'churn', 'objects', 'products', 'creditcard']
fig, axes = plt.subplots(3, sharey=True, figsize=(18,24))
i=1
for col in cols_dist:
    plt.subplot(3,3,i)
    sns.countplot(x=col, data=df,)
    plt.title("Гистограмма \n для признака <<{}>>".format(dict_to[col]))
    plt.xlabel(dict_to[col], fontsize = 12)
    plt.ylabel(dict_to[col], fontsize = 12)
    plt.ylabel('Количество', fontsize = 12)
    i=i+1
# Out:
# <ipython-input-86-c466cf939f29>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i)
# <ipython-input-86-c466cf939f29>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i)
# <ipython-input-86-c466cf939f29>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i)

# %%
sns.countplot(x = 'gender', hue = 'city', data = df);

# %%
sns.violinplot(x= "city", y = "age", hue = 'gender',  data = df);

# %%
# Работа в разрезе категориальных признаков
sns.stripplot(x = 'city', y = 'age',
              hue = "gender",
              data = df);

# %%
sns.swarmplot(x = 'city', y = 'age',
              hue="gender",
              data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 89.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 81.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 81.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##

# %% [markdown]
# Синтаксис plotly несколько отличается от `matplotlib` и `seqborn`.
#
# Здесь мы передаем данные для графиков функция из библиотеки plotly.graph_objects, которую мы импортировали как go, и потом эти графики передаем функции go.Figure, которая собственно строит график.

# %%
import plotly
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
our_data = [2, 3, 1] # задаем данные
our_bar = go.Bar(y = our_data) # передаем данные объекту Bar, говорим, что наши данные, это величина категории по шкале y
fig = go.Figure(data = our_bar) # передаем наш бар объекту Figure, который уже рисует график
fig.show() # выводим график
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Данные разбиты по какой-то категориальной переменной

# %%
trace0 = go.Bar(y = [2, 3, 1])
trace1 = go.Bar(y = [4, 7, 3])
our_data = [trace0, trace1] # когда объектов больше одного - передаем их списком
fig = go.Figure(data = our_data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
trace0 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17]
)
trace1 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[16, 5, 11, 9]
)
our_data = [trace0, trace1]

fig = go.Figure(data = our_data)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Все находящееся внутри осей координат и касающееся данных настраивается внутри объекта, относящимся к данным. Так в объекте `go.Scatter` (который по сути создает словарь, вообще почти все в `plotly` построено на синтаксисе словарей) мы можем прописать тип, цвет и размер маркеров, всплывающий текст и т.д.). В `layout` подписываем шкалы `x` и `y` - обратите внимание, что внутри словаря некторые параметры в свою очередь тоже словари.

# %%
trace0 = go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 15, 13, 17],
    marker={'color': 'red', 'symbol': 101, 'size': 10}, # атрибуты маркера - цвет, код символа, размер
    mode = 'lines+markers', # атрибуты графика. Здесь можно задать просто линию или маркеры, например
    text = ['one', 'two', 'three'], # подписи к точкам
    name = 'Red Trace' # имя в легенде
)

our_data = [trace0]
our_layout = go.Layout(
    title="First Plot",
    xaxis={'title':'x axis'}, # заголовки шкал
    yaxis={'title':'y axis'},
    height = 400,
    width = 700)

# после того, как создали отдельно объекты и для data, и для layout, передаем их функции go.Figure()
fig = go.Figure(data=our_data, layout=our_layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Выполните следующие работы
# 1. Загрузить данные;
# 2. Ознакомиться с данными;
# 3. Провести предобработку данных;
# - заголовки;
# - типы признаков;
# - дубли;
# - пропущенные значения
# 4. Провести исследовательский анализ данных с целью выявления
# - интервальные признаки в разрезе целевого признака: изучение точечных оценок; гистограммы и распределения;
# - категориальные признаки в разрезе целевого признака: изучение точечных оценок; гистограммы.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2 линии нижнего и верхнего усов
#для подсчета значений нижнего и верхнего усов была предложена следующая функция
def calc_boxplot(df_col : pd.Series) -> tuple:

    """
    Функция для расчета значений нижнего и верхнего усов.
    На вход подается столбец датафрейма,
    на выходе кортеж: первый элемент -- нижний ус, второй элемент -- верхний ус
    """

    Q1, median, Q3 = np.percentile(np.asarray(df_col.dropna()), [25, 50, 75])
    IQR = Q3 - Q1
    loval = Q1 - 1.5 * IQR
    hival = Q3 + 1.5 * IQR
    wiskhi = np.compress(np.asarray(df_col.dropna()) <= hival, np.asarray(df_col.dropna()))
    wisklo = np.compress(np.asarray(df_col.dropna()) >= loval, np.asarray(df_col.dropna()))
    actual_hival = np.max(wiskhi)
    actual_loval = np.min(wisklo)
    return actual_loval, actual_hival #(нижний ус, верхний ус)

# %%
# загрузка
df = pd.read_csv('/content/bank_dataset.csv')
df.head(2)
# Out:
#      userid  score       City Gender  Age  Objects   Balance  Products  \
# 0  15677338    619  Ярославль      Ж   42        2       NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1  83807.86         1
#
#    CreditCard  Loyalty  estimated_salary  Churn
# 0           1        1         101348.88      1
# 1           0        1         112542.58      0

# %% [markdown]
# Каждый клиент характеризуется следующим набором данных:
#
# |Признак|Описание признака|
# |---:|:---|
# |`userid`|идентификатор пользователя|
# |`score`|баллы кредитного скоринга|
# |`City`|город|
# |`Gender`|пол|
# |`Age`|возраст|
# |`Objects`|количество объектов в собственности|
# |`Balance`|баланс на счете|
# |`Products`|количество продуктов, которыми пользуется клиент|
# |`CreditCard`|есть ли кредитная карта|
# |`Loyalty`|активный клиент|
# |`estimated_salary`|заработная плата клиента|
# |`Churn`|ушел или нет|

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userid            10000 non-null  int64
#  1   score             10000 non-null  int64
#  2   City              10000 non-null  object
#  3   Gender            10000 non-null  object
#  4   Age               10000 non-null  int64
#  5   Objects           10000 non-null  int64
#  6   Balance           6383 non-null   float64
#  7   Products          10000 non-null  int64
#  8   CreditCard        10000 non-null  int64
#  9   Loyalty           10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  Churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
per = [0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99]
df.describe(percentiles=per)
# Out:
#              userid         score           Age       Objects        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000    6383.000000
# mean   1.573368e+07    650.528800     38.921800      5.012800  119827.493793
# std    7.193619e+04     96.653299     10.487806      2.892174   30095.056462
# min    1.560844e+07    350.000000     18.000000      0.000000    3768.690000
# 1%     1.561124e+07    432.000000     21.000000      0.000000   47505.449000
# 5%     1.562156e+07    489.000000     25.000000      1.000000   70367.943000
# 25%    1.567126e+07    584.000000     32.000000      3.000000  100181.975000
# 50%    1.573347e+07    652.000000     37.000000      5.000000  119839.690000
# 75%    1.579597e+07    718.000000     44.000000      7.000000  139512.290000
# 95%    1.584577e+07    812.000000     60.000000      9.000000  169984.256000
# 99%    1.585585e+07    850.000000     72.000000     10.000000  190495.170600
# ...

# %%
#предобработка
# - переименование заголовков;
# - корректировка типа;
# - поиск дублей;
# - поиск и обработка аномалий;
# - обработка пропущенных значений.

# %%
#переименование заголовков

df.columns = df.columns.str.lower()
df.columns
df.rename(columns={'userid': 'user_id',
                   'creditcard': 'credit_card'},
          inplace=True)

df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
#дубли

df.duplicated().sum()
df.drop(columns='user_id').duplicated().sum()
df.head(2)
# Out:
#     user_id  score       city gender  age  objects   balance  products  \
# 0  15677338    619  Ярославль      Ж   42        2       NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1  83807.86         1
#
#    credit_card  loyalty  estimated_salary  churn
# 0            1        1         101348.88      1
# 1            0        1         112542.58      0

# %%
df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
#поиск и обработка аномальных значений

int_vars = ['score', 'age', 'balance', 'estimated_salary']
cat_vars = ['city', 'gender', 'objects', 'products', 'credit_card', 'loyalty', 'churn']

# %%
#поиск аномальных значений на пример одного признака
#нарисуем ящик с усами -- boxplot

plt.figure(figsize=(4,4))
sns.boxplot(data=df,
            y='age',
            color='yellow')
plt.title('Ящик с усами для признака <<возраст>>', fontsize=10)
plt.ylabel('Возраст, лет', fontsize=10)
plt.show()

# %%
#поиск аномальных значений на пример одного признака
#нарисуем ящик с усами -- boxplot

plt.figure(figsize=(6,6))
sns.boxplot(data=df,
            y='age',
            color='yellow')
actual_loval, actual_hival = calc_boxplot(df['age'])
plt.axhline(actual_hival,
            color='red',
            label=f'Верхний ус -- {actual_hival:.2f}')
plt.axhline(actual_loval,
            color='green',
            label=f'Нижний ус -- {actual_loval:.2f}')
plt.title('Ящик с усами для признака <<возраст>>', fontsize=10)
plt.ylabel('Возраст, лет', fontsize=10)
plt.legend()
plt.show()

# %%
df.loc[df.age.between(18,62)];

# %%
plt.figure(figsize=(6,6))
sns.histplot(data=df,
             x='age',
             color='teal',
             bins=50,
             kde=True)
plt.title('Гистограмма для признака <<возраст>>', fontsize=10)
plt.xlabel('Возраст, лет', fontsize=10)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# определение числа разбиений по формуле Стёрджеса https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%BE_%D0%A1%D1%82%D1%91%D1%80%D0%B4%D0%B6%D0%B5%D1%81%D0%B0
import math
1+3.322*math.log10(df.shape[0])
# Out:
# 14.288

# %%
plt.subplots(nrows=1,
             ncols=2,
             #sharey=True,
             figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(data=df,
            y='age',
            color='yellow')
actual_loval, actual_hival = calc_boxplot(df['age'])
plt.axhline(actual_hival,
            color='red',
            label=f'Верхний ус -- {actual_hival:.2f}')
plt.axhline(actual_loval,
            color='green',
            label=f'Нижний ус -- {actual_loval:.2f}')
plt.title('Ящик с усами для признака <<возраст>>', fontsize=10)
plt.ylabel('Возраст, лет', fontsize=10)
plt.legend()
plt.subplot(1,2,2)
sns.histplot(data=df,
             x='age',
             color='teal',
             bins=50,
             kde=True)
plt.title('Гистограмма для признака <<возраст>>', fontsize=10)
plt.xlabel('Возраст, лет', fontsize=10)
plt.ylabel('Абсолютные частоты', fontsize=10)
plt.axvline(actual_hival,
            color='red',
            label=f'Верхний ус -- {actual_hival:.2f}')
plt.axvline(actual_loval,
            color='green',
            label=f'Нижний ус -- {actual_loval:.2f}')
per_1 = np.nanpercentile(df['age'], 1)
per_99 = np.nanpercentile(df['age'], 99)
plt.axvline(per_1,
            color='blue',
            label=f'1-я перцентиль -- {per_1:.2f}')
plt.axvline(per_99,
            color='black',
            label=f'99-я перцентиль -- {per_99:.2f}')
plt.legend()

# %%
int_vars
# Out:
# ['score', 'age', 'balance', 'estimated_salary']

# %%
dict_to_rus = {'score': 'балл',
               'age': 'возраст',
               'balance': 'баланс',
               'estimated_salary': 'зарплата',
               'city': 'город',
               'gender': 'пол',
               'objects': 'кол-во объектов',
               'products': 'кол-во -продуктов' ,
               'credit_card': 'наличие кредитной карты',
               'loyalty': 'лояльность',
               'churn': 'уход'
               }

# %%
plt.subplots(nrows=4,
             ncols=2,
             #sharey=True,
             figsize=(12,24))
for index, col in enumerate(int_vars, start=0):
    plt.subplot(4,2,2*index+1)
    sns.boxplot(data=df,
            y=col,
            color='yellow')
    actual_loval, actual_hival = calc_boxplot(df[col])
    plt.axhline(actual_hival,
            color='red',
            label=f'Верхний ус -- {actual_hival:.2f}')
    plt.axhline(actual_loval,
            color='green',
            label=f'Нижний ус -- {actual_loval:.2f}')
    plt.title(f"Ящик с усами для признака {dict_to_rus.get(col)}", fontsize=10)
    plt.ylabel(f'Признак {dict_to_rus.get(col)}', fontsize=10)
    plt.legend()
    plt.subplot(4,2,2*index+2)
    sns.histplot(data=df,
             x=col,
             color='teal',
             bins=50,
             kde=True)
    plt.title(f'Гистограмма для признака <<{dict_to_rus.get(col)}>>', fontsize=10)
    plt.xlabel(f'Признак <<{dict_to_rus.get(col)}>>', fontsize=10)
    plt.ylabel('Абсолютные частоты', fontsize=10)
    plt.axvline(actual_hival,
                color='red',
                label=f'Верхний ус -- {actual_hival:.2f}')
    plt.axvline(actual_loval,
                color='green',
                label=f'Нижний ус -- {actual_loval:.2f}')
    per_1 = np.nanpercentile(df[col], 1)
    per_99 = np.nanpercentile(df[col], 99)
    plt.axvline(per_1,
                color='blue',
                label=f'1-я перцентиль -- {per_1:.2f}')
    plt.axvline(per_99,
                color='black',
                label=f'99-я перцентиль -- {per_99:.2f}')
    plt.legend()

# %%
df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
#фильтры на признаки
filtered_score = df.score.between(np.nanpercentile(df['score'], 1), 849)  #850
filtered_age = df.age.between(21, 62)
filtered_balance = df[df.balance.notna()].between(calc_boxplot(df.balance)[0],
                                      calc_boxplot(df.balance)[1])
filtered_estimated_salary = df.estimated_salary.between(1842, 200000)

# %%
#процент потерь
(1 - df.loc[filtered_score
            & filtered_age
            #& filtered_balance
            & filtered_estimated_salary
            ].shape[0] / df.shape[0])*100
# Out:
# 8.550000000000002

# %%
#фильтруем датасет
df = df.loc[filtered_score & filtered_age & filtered_estimated_salary]

# %%
df
# Out:
#        user_id  score            city gender  age  objects    balance  \
# 0     15677338    619       Ярославль      Ж   42        2        NaN
# 1     15690047    608         Рыбинск      Ж   41        1   83807.86
# 2     15662040    502       Ярославль      Ж   42        8  159660.80
# 3     15744090    699       Ярославль      Ж   39        1        NaN
# 5     15616748    645         Рыбинск      М   44        8  113755.78
# ...        ...    ...             ...    ...  ...      ...        ...
# 9995  15648965    771       Ярославль      М   39        5        NaN
# 9996  15612628    516       Ярославль      М   35       10   57369.61
# 9997  15627268    709       Ярославль      Ж   36        7        NaN
# 9998  15725091    772  Ростов Великий      М   42        3   75075.31
# 9999  15671055    792       Ярославль      Ж   28        4  130142.79
#
#       products  credit_card  loyalty  estimated_salary  churn
# 0            1            1        1         101348.88      1
# ...

# %%
# df[(df.balance >= calc_boxplot(df.balance)[0]) |
#    (df.balance <= calc_boxplot(df.balance)[1]) |
#    (df.balance == np.NaN)]

# %%
df.balance
# Out:
# 0             NaN
# 1        83807.86
# 2       159660.80
# 3             NaN
# 5       113755.78
#           ...
# 9995          NaN
# 9996     57369.61
# 9997          NaN
# 9998     75075.31
# 9999    130142.79
# Name: balance, Length: 9145, dtype: float64

# %%
df.shape[0]
# Out:
# 9145

# %%
#поиск и обработка аномальных значений категориальных признаков
for col in cat_vars:
    print(f"Значения признака {col}")
    print(df[col].value_counts())
    print('-'*10)
# Out:
# Значения признака city
# Ярославль         4584
# Ростов Великий    2292
# Рыбинск           2269
# Name: city, dtype: int64
# ----------
# Значения признака gender
# М    4980
# Ж    4165
# Name: gender, dtype: int64
# ----------
# Значения признака objects
# 2     963
# 7     950
# 1     944
# 8     933
# 5     930
# 3     918
# 4     908
# 9     899
# 6     882
# 10    450
# 0     368
# Name: objects, dtype: int64
# ----------
# Значения признака products
# 1    4639
# 2    4203
# 3     247
# 4      56
# Name: products, dtype: int64
# ----------
# Значения признака credit_card
# 1    6446
# 0    2699
# Name: credit_card, dtype: int64
# ----------
# Значения признака loyalty
# 1    4595
# 0    4550
# Name: loyalty, dtype: int64
# ----------
# Значения признака churn
# 0    7278
# 1    1867
# Name: churn, dtype: int64
# ----------

# %%
cat_vars
# Out:
# ['city', 'gender', 'objects', 'products', 'credit_card', 'loyalty', 'churn']

# %%
#анализ аномалий категориальных признаков с помощью графиков

fig, axes = plt.subplots(3, sharey=True, figsize=(18,24))
i=0
for i, col in enumerate(cat_vars):
    plt.subplot(3,3,i+1)
    ax = sns.countplot(x=col, data=df)
    plt.title("Гистограмма \n для признака <<{}>>".format(dict_to_rus[col]))
    plt.xlabel(dict_to_rus[col], fontsize = 12)
    plt.ylabel('Абсолютная частота', fontsize = 12)
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate(#'{:d} ({:.1f}%)'.format(p.get_height(), 100.*y/df.shape[0]),
            '{:.0f}'.format(p.get_height()),
            (x.mean(), y),ha='center', va='bottom', fontsize = 10)
# Out:
# <ipython-input-30-7ceeb5d50ed3>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i+1)
# <ipython-input-30-7ceeb5d50ed3>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i+1)
# <ipython-input-30-7ceeb5d50ed3>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,3,i+1)

# %%
df.columns
# Out:
# Index(['user_id', 'score', 'city', 'gender', 'age', 'objects', 'balance',
#        'products', 'credit_card', 'loyalty', 'estimated_salary', 'churn'],
#       dtype='object')

# %%
df[df.products < 4]
# Out:
#        user_id  score            city gender  age  objects    balance  \
# 0     15677338    619       Ярославль      Ж   42        2        NaN
# 1     15690047    608         Рыбинск      Ж   41        1   83807.86
# 2     15662040    502       Ярославль      Ж   42        8  159660.80
# 3     15744090    699       Ярославль      Ж   39        1        NaN
# 5     15616748    645         Рыбинск      М   44        8  113755.78
# ...        ...    ...             ...    ...  ...      ...        ...
# 9995  15648965    771       Ярославль      М   39        5        NaN
# 9996  15612628    516       Ярославль      М   35       10   57369.61
# 9997  15627268    709       Ярославль      Ж   36        7        NaN
# 9998  15725091    772  Ростов Великий      М   42        3   75075.31
# 9999  15671055    792       Ярославль      Ж   28        4  130142.79
#
#       products  credit_card  loyalty  estimated_salary  churn
# 0            1            1        1         101348.88      1
# ...

# %%
# пропуски есть - обрабатывать не будем

# %%
df.isna().sum()
# Out:
# user_id                0
# score                  0
# city                   0
# gender                 0
# age                    0
# objects                0
# balance             3300
# products               0
# credit_card            0
# loyalty                0
# estimated_salary       0
# churn                  0
# dtype: int64

# %%
# 4.Провести исследовательский анализ данных с целью выявления
# интервальные признаки в разрезе целевого признака: изучение точечных оценок; гистограммы и распределения;
# категориальные признаки в разрезе целевого признака: изучение точечных оценок; гистограммы.

# %%
#считаем выборочные статистики для целевых групп (ушел/ остался)
df.groupby('churn')[int_vars].agg(['mean', 'median']).round(0)
# Out:
#        score          age          balance           estimated_salary  \
#         mean median  mean median      mean    median             mean
# churn
# 0      648.0  651.0  36.0   36.0  119609.0  119797.0         101144.0
# 1      646.0  646.0  44.0   44.0  120742.0  119656.0         102204.0
#
#
#          median
# churn
# 0      100946.0
# 1      102566.0

# %%
fig, axes = plt.subplots(2, figsize=(15,15))
i=0
for i, col in enumerate(int_vars):
    plt.subplot(2,2,i+1)
    ax = sns.histplot(df[df.churn == 0][col], label = 'Оставшиеся', kde=True)
    ax = sns.histplot(df[df.churn == 1][col], label = 'Ушедшие', kde=True)
    plt.title("Гистограмма и плотность \n для признака <<{}>>".format(dict_to_rus[col]))
    plt.xlabel(dict_to_rus[col])
    plt.ylabel('Плотность')
    plt.legend()
# Out:
# <ipython-input-51-6b48750e996f>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,i+1)
# <ipython-input-51-6b48750e996f>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,i+1)

# %%
#начинаем словарь для сбора аномальных значений по признакам
dict_anomals = {'age': [21,62]}

# %%
cat_vars = ['city', 'gender', 'objects', 'products', 'credit_card', 'loyalty']

# %%
cat_vars = ['city', 'gender', 'objects', 'products', 'credit_card', 'loyalty']
fig, axes = plt.subplots(3, figsize=(16,24))
i=0
for i, col in enumerate(cat_vars):
    plt.subplot(3,2,i+1)
    data_all = df[col].value_counts()
    r = (pd.DataFrame([df[df.churn == 0][col].value_counts()/data_all,
              df[df.churn == 1][col].value_counts()/data_all]).T)
    r.columns = ['0','1']
    ax1 = sns.barplot(x = r.index, y = r['0'], data = r, color='seagreen',
                      alpha = 0.5, label = 'Оставшиеся')
    ax2 = sns.barplot(x = r.index, y = r['1'], data = r, color='red',
                      alpha = 0.5, label = 'Ушедшие')
    plt.title("Гистограмма \n для признака <<{}>>".format(dict_to_rus[col]), fontsize = 14)
    plt.xlabel(dict_to_rus[col], fontsize = 14)
    plt.ylabel('Доля клиентов', fontsize = 14)
    plt.legend()
    for p in ax1.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax1.annotate('{:.2f}%'.format(100*y),
            (x.mean(), y),ha='center', va='bottom', fontsize = 10)
# Out:
# <ipython-input-55-cf9000c6bb90>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
# <ipython-input-55-cf9000c6bb90>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
# <ipython-input-55-cf9000c6bb90>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)

# %%
df[(df.city == 'Ростов Великий') & (df.churn == 1)].shape[0] / df[df.city == 'Ростов Великий'].shape[0] * 100
# Out:
# 32.37347294938918

# %% [markdown]
# ### Полезные ссылки
# Сайт проекта [Matplotlib](https://matplotlib.org/)
#
# [Visualization with Matplotlib](https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb)
#
# [Краткое руководство по Matplotlib](https://pyprog.pro/mpl/mpl_short_guide.html)
#
# [Devpractice Team. Python. Визуализация данных. Matplotlib. Seaborn. Mayavi. - devpractice.ru. 2020. - 412 с.](https://devpractice.ru/book-python-data-viz/)
#
# [Как отображать значения на гистограмме Seaborn (с примерами)](https://www.codecamp.ru/blog/seaborn-barplot-show-values/)

# %% [markdown]
# ## Объединение данных
#
# В `pandas` есть несколько методов для [объединения данных](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) из разных датафреймов:
# [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html), [`append()`](https://pandas.pydata.org/pandas-docs/version/1.3/reference/api/pandas.DataFrame.append.html), [`.merge()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) и [`.join()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html).

# %% [markdown]
# ### Метод [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)
#
# Сигнатура метода
#
# ```python
# pandas.concat(objs, axis=0, join='outer', ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=None)
# ```
#
# Отдельные параметр метода
#
# |Параметр|Комментарий|
# |--:|:--|
# |`objs`|список или словарь структур `Series`, `DataFrame` для объединения|
# |`axis`|ось (по умолчанию 0), вдоль которой будет производиться объединение (0 -- индекс: добавляются строки; 1 -- столбцы: добавляются столбцы)|
# |`join`|тип операции объединения:|
# | |'outer' - итоговая структура будет результатом объединения  логическое (ИЛИ) переданных структур|
# | |`inner` -- итоговая структура будет результатом пересечения (логическое И) переданных структур|
# |`ignore_index`|использование индексных меток при объединении: True — не используется; False – используется (по умолчанию)|

# %%
p

# %% [markdown]
# ### Метод [`append()`](https://pandas.pydata.org/pandas-docs/version/1.3/reference/api/pandas.DataFrame.append.html)
#
# Сигнатура метода
#
# ```python
# DataFrame.append(other, ignore_index=False, verify_integrity=False, sort=False)
# ```

# %% [markdown]
# ### Метод [`.merge()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)
#
# Сигнатура метода
# ```python
# DataFrame.merge(right, how='inner', on=None, left_on=None,
# right_on=None, left_index=False, right_index=False, sort=False,
# suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)
# ```
#
# |Параметр|Комментарий|
# |--:|:--|
# |`right`|"правая" `DataFrame` структура|
# |`how`|тип соединения: `left`, `right`, `outer`, `inner`, `cross`|
# ||`left`: использовать только ключи из левого фрейма, аналогично левому внешнему соединению `SQL`; сохранить порядок ключей|
# ||`right`: использовать только ключи из правого фрейма, аналогично правому внешнему соединению `SQL`; сохранить порядок ключей|
# ||`outer`: используйте объединение ключей из обоих фреймов, аналогично полному внешнему соединению `SQL`; сортировать ключи лексикографически|
# ||`inner`: использовать пересечение ключей из обоих фреймов, аналогично внутреннему соединению `SQL`; сохранить порядок левых ключей|
# ||`cross`: создает декартово произведение из обоих фреймов, сохраняет порядок левых ключей|
# |`on`|список имен столбцов для объединения, столбцы должны входить как в левом, так и в правом `DataFrame`|
# |`left_on`|cписок столбцов левого `DataFrame`, которые будут использоваться как ключи|
# |`right_on`|список столбцов из правого `DataFrame`, которые будут использоваться как ключи|
# |`left_index`|если параметр равен `True`, то будет использован индекс (метки строк) из левого `DataFrame` в качестве ключа(ей) для объединения|
# |`right_index`|если параметр равен `True`, то будет использован индекс (метки строк) из правого `DataFrame` в качестве ключа(ей) для объединения|
# |`sort`|если параметр равен `True`, то данные в полученном `DataFrame` будут отсортированы в лексикографическом порядке|

# %% [markdown]
# ### Метод [`.join()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html)
#
# ```python
# DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)[source]
# ```

# %% [markdown]
# Создание датафрейма из нескольких файлов (по строкам)

# %% [markdown]
# Допустим, ваш набор данных распределен по нескольким файлам, но вы хотите собрать набор данных в один датафрейм. Будем также считать, что вы знаете заголовки требуемых столбцов:
#
# |Признак|Комментарий|
# |--:|:--|
# |`user_id`|уникальный идентификатор клиента|
# |`surname`|фамилия клиента|
# |`name`|имя клиента|
# |`date_of_birth`|дата рождения клиента|
#
# Предположим также, что исходные данные хранятся в файлах `user1.csv`, `user2.csv` и `user3.csv`.
#
# Вы можете прочитать каждый CSV-файл в свой собственный DataFrame, объединить их вместе, а затем удалить исходные DataFrames, но это будет неэффективно с точки зрения использования памяти и потребует большого количества кода.
#
# Лучшим решением является использование встроенного модуля `glob`.
#
# Однако прежде прочтем один файл и посмотрим на его структуру.

# %%
read_columns = ['user_id', 'surname', 'name', 'date_of_birth']

# %%
pd.read_csv('user1.csv',
            usecols = read_columns)
# Out:
#    user_id    surname     name date_of_birth
# 0       11    Сидоров     Иван    1982-05-04
# 1       12     Иванов  Николай    1983-09-12
# 2       13     Петров     Петр    1983-12-12
# 3       14  Гришечкин  Алексей    1985-01-13
# 4       15  Афанасьев   Сергей    1986-08-15
# 5       16      Мимин   Андрей    1985-01-15

# %%
from glob import glob

# %% [markdown]
# Вы можете передать шаблон в `glob()`, включая подстановочные знаки, и он вернет список всех файлов, соответствующих этому шаблону.
#
# В этом случае метод `glob` в папке `data` ищет все `CSV`-файлы, начинающиеся со слова `user`.

# %%
stock_files = sorted(glob('user*.csv'))
#stock_files = ['1.csv', 'test.csv']
stock_files
# Out:
# ['user1.csv', 'user2.csv', 'user3.csv']

# %% [markdown]
# `glob` возвращает имена файлов в произвольном порядке, поэтому мы отсортировали список с помощью встроенной в Python функции `sorted()`.
#
# Затем мы можем использовать выражение генератора для чтения каждого из файлов с помощью `read_csv()` и передать результаты функции `concat()`, которая объединит строки в один `DataFrame`

# %%
pd.concat((pd.read_csv(file) for file in stock_files))
# Out:
#    Unnamed: 0  user_id    surname       name date_of_birth     city
# 0           0       11    Сидоров       Иван    1982-05-04      NaN
# 1           1       12     Иванов    Николай    1983-09-12      NaN
# 2           2       13     Петров       Петр    1983-12-12      NaN
# 3           3       14  Гришечкин    Алексей    1985-01-13      NaN
# 4           4       15  Афанасьев     Сергей    1986-08-15      NaN
# 5           5       16      Мимин     Андрей    1985-01-15      NaN
# 0           0       23    Петрова  Анастасия    1986-02-12      NaN
# 1           1       24   Сидорова    Людмила    1984-12-25      NaN
# 2           2       25    Иванова      Ирина    1986-04-15      NaN
# 3           3       26    Фирсова       Анна    1985-06-23      NaN
# 0           0       33     Малкин   Афанасий    1986-05-12     Орел
# 1           1       34   Протасов      Тарас    1992-12-25  Воронеж
# 2           2       35   Кочергин   Григорий    1987-02-25     Елец

# %% [markdown]
# К сожалению, теперь в индексе есть повторяющиеся значения. Чтобы избежать этого, мы можем указать функции `concat()` игнорировать индекс и вместо этого использовать целочисленный индекс по умолчанию.

# %%
pd.concat((pd.read_csv(file, usecols = read_columns) for file in stock_files), ignore_index=True)
# Out:
#     user_id    surname       name date_of_birth
# 0        11    Сидоров       Иван    1982-05-04
# 1        12     Иванов    Николай    1983-09-12
# 2        13     Петров       Петр    1983-12-12
# 3        14  Гришечкин    Алексей    1985-01-13
# 4        15  Афанасьев     Сергей    1986-08-15
# 5        16      Мимин     Андрей    1985-01-15
# 6        23    Петрова  Анастасия    1986-02-12
# 7        24   Сидорова    Людмила    1984-12-25
# 8        25    Иванова      Ирина    1986-04-15
# 9        26    Фирсова       Анна    1985-06-23
# 10       33     Малкин   Афанасий    1986-05-12
# 11       34   Протасов      Тарас    1992-12-25
# 12       35   Кочергин   Григорий    1987-02-25

# %% [markdown]
# Создание датафрейма из нескольких файлов (по столбцам)

# %% [markdown]
# Предположим теперь, что каждый файл будет содержать столбцы из единого набора данных. Давайте соберем единый датафрейм из столбцов, содержащихся в разных файлах.

# %%
pd.read_csv('user1.csv').head()
# Out:
#    Unnamed: 0  user_id    surname     name date_of_birth
# 0           0       11    Сидоров     Иван    1982-05-04
# 1           1       12     Иванов  Николай    1983-09-12
# 2           2       13     Петров     Петр    1983-12-12
# 3           3       14  Гришечкин  Алексей    1985-01-13
# 4           4       15  Афанасьев   Сергей    1986-08-15

# %%
pd.read_csv('session_user1.csv').head()
# Out:
#    Unnamed: 0  session_id           time_start             time_end
# 0           0        1111  1982-05-04:12-35-56  1982-05-04:13-05-34
# 1           1        1222  1983-09-12:23-01-06  1983-09-12:23-05-56
# 2           2        1333  1983-12-12:05-25-13  1983-12-12:06-00-06
# 3           3        1444  1985-01-13:10-39-24  1985-01-13:10-40-56
# 4           4        1555  1986-08-15:12-37-42  1986-08-15:14-18-19

# %% [markdown]
# Создадим верную последовательность файлов для чтения.

# %%
lst_file = ['user1.csv', 'session_user1.csv']

# %% [markdown]
# С помощью метода `concat()` выполним конкатенацию данных вдоль оси столбцов

# %%
df = pd.concat((pd.read_csv(file) for file in lst_file), axis='columns').head()
df
# Out:
#    Unnamed: 0  user_id    surname     name date_of_birth  Unnamed: 0  \
# 0           0       11    Сидоров     Иван    1982-05-04           0
# 1           1       12     Иванов  Николай    1983-09-12           1
# 2           2       13     Петров     Петр    1983-12-12           2
# 3           3       14  Гришечкин  Алексей    1985-01-13           3
# 4           4       15  Афанасьев   Сергей    1986-08-15           4
#
#    session_id           time_start             time_end
# 0        1111  1982-05-04:12-35-56  1982-05-04:13-05-34
# 1        1222  1983-09-12:23-01-06  1983-09-12:23-05-56
# 2        1333  1983-12-12:05-25-13  1983-12-12:06-00-06
# 3        1444  1985-01-13:10-39-24  1985-01-13:10-40-56
# 4        1555  1986-08-15:12-37-42  1986-08-15:14-18-19

# %%
df.drop(columns = ['Unnamed: 0'], inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user_id        5 non-null      int64
#  1   surname        5 non-null      object
#  2   name           5 non-null      object
#  3   date_of_birth  5 non-null      object
#  4   session_id     5 non-null      int64
#  5   time_start     5 non-null      object
#  6   time_end       5 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 408.0+ bytes

# %% [markdown]
# Создание датафреймов из нескольких файлов

# %%
list_dict = {'Таблица "Информация о посещениях сайта"' : '/data/visits_log.csv',
            'Таблица "Информация о заказах"' : '/data/orders_log.csv',
             'Таблица "Информация о расходах на маркетинг"' : '/data/costs.csv',
            }
df_list=[]
for i in list_dict.values():
    df_list.append(pd.read_csv(i))
    print('Прочитан файл {}'.format(i))
globals()['df'+'_clients'] = df_list[0]

# %% [markdown]
# Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Необходимо сделать предварительный анализ тарифов на небольшой выборке клиентов -- 500 пользователей. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
#
# **Описание тарифов**
#
# |**Услуги**|**Тариф «Смарт»**|**Тариф «Ультра»**|
# |:------|:------|:-----|
# Ежемесячная плата | 550 рублей| 1950 рублей|
# Включено | 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика| Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика|
# Стоимость услуг сверх тарифного пакета | минута разговора: 3 рубля; сообщение: 3 рубля; 1 Гб интернет-трафика: 200 рублей | минута разговора: 1 рубль; сообщение: 1 рубль; 1 Гб интернет-трафика: 150 рублей|
#
# Обратите внимание: Компания всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута.
#
# **Имеются следующие таблицы**
#
# Таблица `users` (информация о пользователях):
#
# |Имя поля|Описание поля|
# |-------------:|:------------|
# |**user_id** | уникальный идентификатор пользователя|
# |**first_name** | имя пользователя|
# |**last_name** | фамилия пользователя|
# |**age** | возраст пользователя (годы)|
# |**reg_date** | дата подключения тарифа (день, месяц, год)|
# |**churn_date** | дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)|
# |**city** | город проживания пользователя|
# |**tariff** | название тарифного плана|
#
# Таблица `calls` (информация о звонках):
#
# |Имя поля|Описание поля|
# |-------------:|:------------|
# |**id** | уникальный номер звонка|
# |**call_date** | дата звонка|
# |**duration** | длительность звонка в минутах|
# |**user_id** | идентификатор пользователя, сделавшего звонок|
#
# Таблица `messages` (информация о сообщениях):
#
# |Имя поля|Описание поля|
# |-------------:|:------------|
# |**id** | уникальный номер сообщения|
# |**message_date** | дата сообщения|
# |**user_id** |  идентификатор пользователя, отправившего сообщение|
#
# Таблица `internet` (информация об интернет-сессиях):
#
# |Имя поля|Описание поля|
# |-------------:|:------------|
# |**id** | уникальный номер сессии|
# |**mb_used** | объём потраченного за сессию интернет-трафика (в мегабайтах)|
# |**session_date** | дата интернет-сессии|
# |**user_id** | идентификатор пользователя|
#
# Таблица `tariffs` (информация о тарифах):
#
# |Имя поля|Описание поля|
# |-------------:|:------------|
# |**tariff_name** | название тарифа|
# |**rub_monthly_fee** | ежемесячная абонентская плата в рублях|
# |**minutes_included** | количество минут разговора в месяц, включённых в абонентскую плату|
# |**messages_included** | количество сообщений в месяц, включённых в абонентскую плату|
# |**mb_per_month_included** | объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)|
# |**rub_per_minute** | стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)|
# |**rub_per_message** | стоимость отправки сообщения сверх тарифного пакета|
# |**rub_per_gb** | стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)|
#
#
# Инструкция по выполнению проекта
#
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
#
# -загрузите файлы и изучите общую информацию;
#
# **Шаг 2. Подготовьте данные**
# - Приведите данные к нужным типам;
# - Найдите и исправьте ошибки в данных. Обратите внимание, что длительность многих звонков — 0.0 минут.
# - Посчитайте для каждого пользователя:
#     - количество сделанных звонков и израсходованных минут разговора по месяцам;
#     - количество отправленных сообщений по месяцам;
#     - объем израсходованного интернет-трафика по месяцам;
#     - помесячную выручку с каждого пользователя (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножьте на значение из тарифного плана; прибавьте абонентскую плату, соответствующую тарифному плану).
#
# **Шаг 3. Проанализируйте данные**
#
# Опишите поведение клиентов оператора:
# - Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа в месяц?
# - Посчитайте среднее количество, дисперсию и стандартное отклонение.
# - Постройте гистограммы.
# - Опишите распределения.
#
# **Шаг 4. Проверьте гипотезы**
# - средняя выручка пользователей тарифов «Ультра» и «Смарт» различается;
# - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#первый способ чтения данных из нескольких датафреймов
#просто считаем каждый файл в отдельный датафрейм

# df_users = pd.read_csv('/content/users.csv')
# df_calls = pd.read_csv('/content/calls.csv')
# df_messages = pd.read_csv('/content/messages.csv')
# df_internet = pd.read_csv('/content/internet.csv')
# df_tariffs = pd.read_csv('/content/tariffs.csv')

# %%
# считывание файлов с помощью цикла

#создаем словарь с путями к файлам
list_dict = {'Таблица "Информация пользователях"' : '/content/users.csv',
             'Таблица "Информация о звонках"' : '/content/calls.csv',
             'Таблица "Информация о сообщениях"' : '/content/messages.csv',
             'Таблица "Информация о траффике"' : '/content/internet.csv',
             'Таблица "Информация о тарифах"' : '/content/tariffs.csv'
            }
#считываем файл в датафрейм и добавляем его в список
#на выходе получили спискок датафреймов

df_list=[]
for i in list_dict.values():
    df_list.append(pd.read_csv(i))
    print('Прочитан файл {}'.format(i))
#globals()['df'+'_clients'] = df_list[0]
# Out:
# Прочитан файл /content/users.csv
# Прочитан файл /content/calls.csv
# Прочитан файл /content/messages.csv
# Прочитан файл /content/internet.csv
# Прочитан файл /content/tariffs.csv

# %%
# возможность применения сразу нескольких методов к одному датафрейму
for df in df_list:
    print('----'*10)
    display(df.head(2))
    display(df.info())
    display(df.describe())
    print('----'*10)
# Out:
# ----------------------------------------
#    user_id  age churn_date       city first_name  last_name    reg_date tariff
# 0     1000   52        NaN  Краснодар     Рафаил  Верещагин  2018-05-25  ultra
# 1     1001   41        NaN     Москва       Иван       Ежов  2018-11-01  smart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
#            user_id        age
# count   500.000000  500.00000
# mean   1249.500000   46.58800
# ...

# %% [markdown]
# {'Таблица "Информация пользователях"' : '/content/users.csv',
#              'Таблица "Информация о звонках"' : '/content/calls.csv',
#              'Таблица "Информация о сообщениях"' : '/content/messages.csv',
#              'Таблица "Информация о траффике"' : '/content/internet.csv',
#              'Таблица "Информация о тарифах"' : '/content/tariffs.csv'
#             }
