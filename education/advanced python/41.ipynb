# %% [markdown]
# # <font color='#11a642' size='6'> **Импорт и установка библиотек**

# %%
pip install category_encoders -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.5 MB/s eta 0:00:00

# %%
# !pip install shap -q

# %%
from google.colab import drive
import json
import zipfile

import pandas as pd

# %%
import random
import pandas as pd
pd.set_option("display.max_columns", 100)
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder



from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.impute import KNNImputer, SimpleImputer

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# import category_encoders as ce
from category_encoders.basen import BaseNEncoder
from category_encoders import TargetEncoder

from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, f1_score

from sklearn.inspection import permutation_importance
import shap

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from category_encoders import TargetEncoder

# %%
def calculate_metrics_and_plot_roc_comparison(
    model,
    X_train: np.ndarray,
    y_train: np.ndarray,
    X_test: np.ndarray,
    y_test: np.ndarray,
    best_threshold: float
) -> dict:
    """
    Рассчитывает метрики классификации и строит ROC-кривые для train и test выборок на одном графике.

    Параметры:
    ----------
    model :
        Обученная модель, реализующая метод predict_proba.

    X_train : np.ndarray
        Признаки обучающей выборки.

    y_train : np.ndarray
        Истинные метки классов обучающей выборки.

    X_test : np.ndarray
        Признаки тестовой выборки.

    y_test : np.ndarray
        Истинные метки классов тестовой выборки.

    best_threshold: float
      Порог для бинарного прогноза.

    Возвращает:
    -----------
    metrics : dict
        Словарь с метриками для обеих выборок.
    """
    results = {}

    for X, y, sample_type in [(X_train, y_train, "train"), (X_test, y_test, "test")]:
        # Предсказание вероятностей
        y_proba = model.predict_proba(X)[:, 1]

        # Прогноз с учетом порога
        y_pred = (y_proba >= 0.5).astype(int)

        # Вычисление метрик
        precision = precision_score(y, y_pred)
        recall = recall_score(y, y_pred)
        roc_auc = roc_auc_score(y, y_proba)
        fpr, tpr, _ = roc_curve(y, y_proba)

        # Сохранение результатов
        results[sample_type] = {
            'precision': precision,
            'recall': recall,
            'roc_auc': roc_auc,
            'fpr': fpr,
            'tpr': tpr,
            'threshold': best_threshold
        }


    # Построение ROC-кривых на одном графике
    plt.figure(figsize=(10, 8))

    colors = {'train': 'blue', 'test': 'red'}
    for sample_type in ['train', 'test']:
        plt.plot(
            results[sample_type]['fpr'],
            results[sample_type]['tpr'],
            color=colors[sample_type],
            lw=2,
            label=f'{sample_type.capitalize()} (AUC = {results[sample_type]["roc_auc"]:.2f})'
        )

    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title(f'ROC Curves Comparison ({type(model).__name__})', fontsize=14)
    plt.legend(loc="lower right", fontsize=12)
    plt.grid(True, alpha=0.3)
    plt.show()

    return results

# %% [markdown]
# # <font color='#11a642' size='6'> **Загрузка данных**

# %%
def load_dataset(from_kaggle:bool = False) -> pd.DataFrame:
  '''
  Функция скачивает данные с сайта kaggle, если установлен from_kaggle=True,
  инчае архив считывается по ссылке с гугл диска (такой способ удобен тем, у кого нет доступа к kaggle)
  params:
      - from_kaggle - индикатор откуда скачивать данные (True - c сайта kaggle, False -  c google диска)
  return:
      - pd.DataFrame

  '''
  if from_kaggle:
    # запросит разрешение к гугл диску, необходимо дать это разрешение
    drive.mount('/content/drive')
    # установим kaggle
    # !pip install kaggle -q
    # !mkdir ~/.kaggle
    # копируем kaggle.json (предварительно, необходимо сгенерить токен на
    # сайте kaggle и сохранить к себе на гугл диск) в папку ~/.kaggle/
    # !cp "/content/drive/MyDrive/Colab Notebooks/config/kaggle.json" ~/.kaggle/
    # !kaggle competitions download -c playground-series-s5e7
    # !kaggle competitions download -c playground-series-s5e3
  else:
    # !gdown 1-730JF1IWA5e_ejuXWLmkkzHFvudisdp
  # распаковка архива
  zip_ref = zipfile.ZipFile('playground-series-s5e7.zip', 'r')
  zip_ref.extractall()
  zip_ref.close()
  df_train = pd.read_csv('train.csv')
  df_test = pd.read_csv('test.csv')
  df_sample_submission = pd.read_csv('sample_submission.csv')
  return df_train, df_test, df_sample_submission

# %% [markdown]
# Time_spent_Alone: Количество часов, проводимых в одиночестве ежедневно (0–11).
#
# Stage_fear: Наличие страха сцены (Да/Нет).
#
# Social_event_attendance: Частота посещения социальных мероприятий (0–10).
#
# Going_outside: Частота выхода из дома (0–7).
#
# Drained_after_socializing: Чувство опустошения после общения (Да/Нет).
#
# Friends_circle_size: Количество близких друзей (0–15).
#
# Post_frequency: Частота публикаций в соцсетях (0–10).
#
# Personality: Целевая переменная (Экстраверт/Интроверт).

# %%
df_train, df_test, df_sample_submission = load_dataset(from_kaggle = True)
# Out:
# Mounted at /content/drive
# Downloading playground-series-s5e7.zip to /content
#   0% 0.00/191k [00:00<?, ?B/s]
# 100% 191k/191k [00:00<00:00, 579MB/s]

# %%
df_train
# Out:
#           id  Time_spent_Alone Stage_fear  Social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        Going_outside Drained_after_socializing  Friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                       NaN                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        Post_frequency Personality
# 0                 5.0   Extrovert
# 1                 8.0   Extrovert
# 2                 0.0   Introvert
# 3                 5.0   Extrovert
# 4                 NaN   Extrovert
# ...               ...         ...
# 18519             7.0   Extrovert
# 18520             5.0   Extrovert
# 18521             NaN   Introvert
# 18522             2.0   Introvert
# 18523             7.0   Extrovert
#
# [18524 rows x 9 columns]

# %%
df_train.columns = (col.lower().replace("(", "_").replace(")", "").replace(" ", "_") for col in df_train.columns)

# %%
df_train.head()
# Out:
#    id  time_spent_alone stage_fear  social_event_attendance  going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   drained_after_socializing  friends_circle_size  post_frequency personality
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert

# %%
df_test.columns = (col.lower().replace("(", "_").replace(")", "").replace(" ", "_") for col in df_test.columns)

# %%
df_train['personality'].unique()
# Out:
# array(['Extrovert', 'Introvert'], dtype=object)

# %%
dict_personality = {'Extrovert':0, 'Introvert':1}
df_train['int_personality'] = df_train['personality'].map(dict_personality)

# %%
df_train.shape
# Out:
# (18524, 10)

# %%
df_train.describe(include='all').T
# Out:
#                              count unique        top   freq      mean  \
# id                         18524.0    NaN        NaN    NaN    9261.5
# time_spent_alone           17334.0    NaN        NaN    NaN  3.137764
# stage_fear                   16631      2         No  12609       NaN
# social_event_attendance    17344.0    NaN        NaN    NaN  5.265106
# going_outside              17058.0    NaN        NaN    NaN  4.044319
# drained_after_socializing    17375      2         No  13313       NaN
# friends_circle_size        17470.0    NaN        NaN    NaN  7.996737
# post_frequency             17260.0    NaN        NaN    NaN  4.982097
# personality                  18524      2  Extrovert  13699       NaN
# int_personality            18524.0    NaN        NaN    NaN  0.260473
#
#                                    std  min      25%     50%       75%  \
# id                         5347.562529  0.0  4630.75  9261.5  13892.25
# time_spent_alone              3.003786  0.0      1.0     2.0       4.0
# stage_fear                         NaN  NaN      NaN     NaN       NaN
# social_event_attendance       2.753359  0.0      3.0     5.0       8.0
# going_outside                  2.06258  0.0      3.0     4.0       6.0
# drained_after_socializing          NaN  NaN      NaN     NaN       NaN
# friends_circle_size           4.223484  0.0      5.0     8.0      12.0
# post_frequency                2.879139  0.0      3.0     5.0       7.0
# personality                        NaN  NaN      NaN     NaN       NaN
# int_personality               0.438905  0.0      0.0     0.0       1.0
#
#                                max
# id                         18523.0
# time_spent_alone              11.0
# stage_fear                     NaN
# social_event_attendance       10.0
# going_outside                  7.0
# drained_after_socializing      NaN
# friends_circle_size           15.0
# post_frequency                10.0
# personality                    NaN
# int_personality                1.0

# %%
df_train['stage_fear'].value_counts(normalize=True, dropna=False)
# Out:
# stage_fear
# No     0.680685
# Yes    0.217124
# NaN    0.102192
# Name: proportion, dtype: float64

# %%
df_train['drained_after_socializing'].value_counts(normalize=True, dropna=False)
# Out:
# drained_after_socializing
# No     0.718689
# Yes    0.219283
# NaN    0.062028
# Name: proportion, dtype: float64

# %%
df_train['social_event_attendance'].value_counts(normalize=True, dropna=False)
# Out:
# social_event_attendance
# 4.0     0.111909
# 9.0     0.111369
# 7.0     0.109642
# 5.0     0.107158
# 6.0     0.107104
# 8.0     0.104999
# 3.0     0.091935
# NaN     0.063701
# 2.0     0.057385
# 0.0     0.056953
# 1.0     0.052796
# 10.0    0.025049
# Name: proportion, dtype: float64

# %% [markdown]
# > social_event_attendance -> 0

# %%
df_train['friends_circle_size'].isna().mean()
# Out:
# np.float64(0.05689915784927661)

# %% [markdown]
# > friends_circle_size -> mean
#
# > на будущее: можно заменить моделью

# %%
df_train.groupby('personality')['friends_circle_size'].mean()
# Out:
# personality
# Extrovert    9.624587
# Introvert    3.263923
# Name: friends_circle_size, dtype: float64

# %%
df_train['post_frequency'].isna().mean()
# Out:
# np.float64(0.06823580220254805)

# %%
df_train[pd.isna(df_train['post_frequency'])].isna().sum()
# Out:
# id                              0
# time_spent_alone               52
# stage_fear                     46
# social_event_attendance        42
# going_outside                  54
# drained_after_socializing      31
# friends_circle_size            48
# post_frequency               1264
# personality                     0
# int_personality                 0
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# id                              0
# time_spent_alone             1190
# stage_fear                   1893
# social_event_attendance      1180
# going_outside                1466
# drained_after_socializing    1149
# friends_circle_size          1054
# post_frequency               1264
# personality                     0
# int_personality                 0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df_train)
# Out:
# <Axes: >

# %%
# df_train = df.copy()

# %% [markdown]
# ## <font color='#11a642' size='5'> Определить роли для независимых признаков

# %%
id_features = ['id', ]
target = 'int_personality'
exclude_features = ['personality',]
bin_features = []

num_features = [col for col in df_train.select_dtypes(include='number').columns
                if col not in id_features + [target, ] + bin_features + exclude_features]

cat_features = [col for col in df_train.select_dtypes(exclude='number').columns
                if col not in id_features + [target, ] + bin_features + exclude_features]

# %%
num_features
# Out:
# ['time_spent_alone',
#  'social_event_attendance',
#  'going_outside',
#  'friends_circle_size',
#  'post_frequency']

# %%
cat_features
# Out:
# ['stage_fear', 'drained_after_socializing']

# %% [markdown]
# # <font color='#11a642' size='6'> **Разведочный анализ данных**

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18524 entries, 0 to 18523
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         18524 non-null  int64
#  1   time_spent_alone           17334 non-null  float64
#  2   stage_fear                 16631 non-null  object
#  3   social_event_attendance    17344 non-null  float64
#  4   going_outside              17058 non-null  float64
#  5   drained_after_socializing  17375 non-null  object
#  6   friends_circle_size        17470 non-null  float64
#  7   post_frequency             17260 non-null  float64
#  8   personality                18524 non-null  object
#  9   int_personality            18524 non-null  int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.4+ MB

# %%
df_train.isna().sum()[df_train.isna().sum()>0]
# Out:
# time_spent_alone             1190
# stage_fear                   1893
# social_event_attendance      1180
# going_outside                1466
# drained_after_socializing    1149
# friends_circle_size          1054
# post_frequency               1264
# dtype: int64

# %%
# sns.pairplot(df_train)

# %%
df_train
# Out:
#           id  time_spent_alone stage_fear  social_event_attendance  \
# 0          0               0.0         No                      6.0
# 1          1               1.0         No                      7.0
# 2          2               6.0        Yes                      1.0
# 3          3               3.0         No                      7.0
# 4          4               1.0         No                      4.0
# ...      ...               ...        ...                      ...
# 18519  18519               3.0         No                      7.0
# 18520  18520               1.0        NaN                      6.0
# 18521  18521               7.0        Yes                      1.0
# 18522  18522               NaN        Yes                      1.0
# 18523  18523               1.0         No                      8.0
#
#        going_outside drained_after_socializing  friends_circle_size  \
# 0                4.0                        No                 15.0
# 1                3.0                        No                 10.0
# 2                0.0                       NaN                  3.0
# 3                3.0                        No                 11.0
# 4                4.0                        No                 13.0
# ...              ...                       ...                  ...
# 18519            3.0                        No                  9.0
# 18520            7.0                        No                  6.0
# 18521            1.0                       Yes                  1.0
# 18522            0.0                       Yes                  5.0
# 18523            6.0                        No                  4.0
#
#        post_frequency personality  int_personality
# 0                 5.0   Extrovert                0
# 1                 8.0   Extrovert                0
# 2                 0.0   Introvert                1
# 3                 5.0   Extrovert                0
# 4                 NaN   Extrovert                0
# ...               ...         ...              ...
# 18519             7.0   Extrovert                0
# 18520             5.0   Extrovert                0
# 18521             NaN   Introvert                1
# 18522             2.0   Introvert                1
# 18523             7.0   Extrovert                0
#
# [18524 rows x 10 columns]

# %%
sns.barplot(df_train[target].value_counts(normalize=True))
# Out:
# <Axes: xlabel='int_personality', ylabel='proportion'>

# %% [markdown]
# # <font color='#11a642' size='6'> **Разделите данные на трейн и тест**

# %%
df_train.head()
# Out:
#    id  time_spent_alone stage_fear  social_event_attendance  going_outside  \
# 0   0               0.0         No                      6.0            4.0
# 1   1               1.0         No                      7.0            3.0
# 2   2               6.0        Yes                      1.0            0.0
# 3   3               3.0         No                      7.0            3.0
# 4   4               1.0         No                      4.0            4.0
#
#   drained_after_socializing  friends_circle_size  post_frequency personality  \
# 0                        No                 15.0             5.0   Extrovert
# 1                        No                 10.0             8.0   Extrovert
# 2                       NaN                  3.0             0.0   Introvert
# 3                        No                 11.0             5.0   Extrovert
# 4                        No                 13.0             NaN   Extrovert
#
#    int_personality
# 0                0
# 1                0
# 2                1
# 3                0
# 4                0

# %%
df_train[num_features + cat_features + bin_features ].loc[75, :]
# Out:
# time_spent_alone              2.0
# social_event_attendance       7.0
# going_outside                 5.0
# friends_circle_size          10.0
# post_frequency                8.0
# stage_fear                     No
# drained_after_socializing      No
# Name: 75, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(df_train[num_features + cat_features + bin_features ],
                                                    df_train[target],
                                                    stratify=df_train[target],
                                                    train_size=0.7,
                                                    random_state=12345)

# %%
X_test.head()
# Out:
#        time_spent_alone  social_event_attendance  going_outside  \
# 14278               3.0                      9.0            NaN
# 13600               3.0                      9.0            6.0
# 15231               1.0                      4.0            6.0
# 16344               NaN                      5.0            6.0
# 16080               3.0                      6.0            7.0
#
#        friends_circle_size  post_frequency stage_fear  \
# 14278                  8.0             5.0         No
# 13600                 10.0             7.0         No
# 15231                 12.0             4.0         No
# 16344                  4.0             NaN         No
# 16080                 13.0             7.0         No
#
#       drained_after_socializing
# 14278                        No
# 13600                        No
# 15231                        No
# 16344                        No
# 16080                        No

# %%
X_test.shape , X_train.shape
# Out:
# ((5558, 7), (12966, 7))

# %% [markdown]
# # <font color='#11a642' size='6'> **Подготовка данных к обучению**

# %% [markdown]
# ## c pipeline

# %%
# SimpleImputer + OHE
cat_pipe = Pipeline(
    [

        (
            'enc',
            TargetEncoder(cols = cat_features)

         ),
        (
            'imputer',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),

    ]
)

# %%
# TODO разделить pipeline: некоторые переменные -0 , некоторые среднее (или модель)
num_pipe = Pipeline(
    [
        (
            'scaler',
            StandardScaler()
        ),
        (
            'imputer',
            SimpleImputer(missing_values=np.nan, strategy='mean')
        ),

    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [
        ('cat', cat_pipe, cat_features),
        ('num', num_pipe, num_features),
    ],
    remainder='passthrough'
)

# %%
type(data_preprocessor.fit_transform(X_train, y_train))
# Out:
# numpy.ndarray

# %%
data_preprocessor.get_feature_names_out()
# Out:
# array(['cat__stage_fear', 'cat__drained_after_socializing',
#        'num__time_spent_alone', 'num__social_event_attendance',
#        'num__going_outside', 'num__friends_circle_size',
#        'num__post_frequency'], dtype=object)

# %%
X_train_p = pd.DataFrame(
    data_preprocessor.fit_transform(X_train, y_train),
    columns=data_preprocessor.get_feature_names_out()
)

X_test_p = pd.DataFrame(
    data_preprocessor.transform(X_test),
    columns=data_preprocessor.get_feature_names_out()
)

# %%
X_train_p.head()
# Out:
#    cat__stage_fear  cat__drained_after_socializing  num__time_spent_alone  \
# 0         0.942796                        0.942476          -7.079100e-17
# 1         0.023593                        0.023766          -4.290108e-02
# 2         0.942796                        0.942476           6.242354e-01
# 3         0.023593                        0.023766           2.906672e-01
# 4         0.023593                        0.023766          -1.043606e+00
#
#    num__social_event_attendance  num__going_outside  num__friends_circle_size  \
# 0                     -1.912239        3.456179e-17                 -0.951151
# 1                     -0.820964       -2.164162e-02                 -0.714301
# 2                     -0.820964       -1.476837e+00                 -1.661700
# 3                     -0.457205        1.433554e+00                 -0.003752
# 4                     -0.457205       -5.067068e-01                  0.706798
#
#    num__post_frequency
# 0        -1.588265e-17
# 1        -6.892566e-01
# 2        -1.730729e+00
# 3        -3.420991e-01
# 4         6.993733e-01

# %%
X_test_p.head()
# Out:
#    cat__stage_fear  cat__drained_after_socializing  num__time_spent_alone  \
# 0         0.023593                        0.023766          -4.290108e-02
# 1         0.023593                        0.023766          -4.290108e-02
# 2         0.023593                        0.023766          -7.100375e-01
# 3         0.023593                        0.023766          -7.079100e-17
# 4         0.023593                        0.023766          -4.290108e-02
#
#    num__social_event_attendance  num__going_outside  num__friends_circle_size  \
# 0                      1.361586        3.456179e-17                 -0.003752
# 1                      1.361586        9.484888e-01                  0.469948
# 2                     -0.457205        9.484888e-01                  0.943648
# 3                     -0.093447        9.484888e-01                 -0.951151
# 4                      0.270311        1.433554e+00                  1.180497
#
#    num__post_frequency
# 0         5.058342e-03
# 1         6.993733e-01
# 2        -3.420991e-01
# 3        -1.588265e-17
# 4         6.993733e-01

# %% [markdown]
# # <font color='#11a642' size='6'> **Построение моделей**

# %% [markdown]
# ## <font color='blue' size='5'> **Логистическая регрессия**

# %%
model_log_reg = LogisticRegression()

# %%
model_log_reg.fit(X_train_p, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_test = model_log_reg.predict_proba(X_test_p)

# %%
y_pred_train = model_log_reg.predict_proba(X_train_p)

# %%
X_train_p.columns
# Out:
# Index(['cat__stage_fear', 'cat__drained_after_socializing',
#        'num__time_spent_alone', 'num__social_event_attendance',
#        'num__going_outside', 'num__friends_circle_size',
#        'num__post_frequency'],
#       dtype='object')

# %%
model_log_reg.coef_[0]
# Out:
# array([ 1.89417211,  2.76696043,  0.56757905, -0.28287025, -0.23978822,
#        -0.29432601, -0.35636873])

# %%
feature_imp = pd.DataFrame({'feature': list(X_train_p.columns), 'coef': model_log_reg.coef_[0]} )
feature_imp.sort_values('coef', ascending=False)
# Out:
#                           feature      coef
# 1  cat__drained_after_socializing  2.766960
# 0                 cat__stage_fear  1.894172
# 2           num__time_spent_alone  0.567579
# 4              num__going_outside -0.239788
# 3    num__social_event_attendance -0.282870
# 5        num__friends_circle_size -0.294326
# 6             num__post_frequency -0.356369

# %%
plt.figure(figsize=(8, 6))
sns.barplot(feature_imp.sort_values('coef', ascending=False), y = 'feature', x='coef')
# Out:
# <Axes: xlabel='coef', ylabel='feature'>

# %%
res = calculate_metrics_and_plot_roc_comparison(
    model_log_reg,
    X_train_p,
    y_train,
    X_test_p,
    y_test,
    0.5)

# %% [markdown]
# ## <font color='blue' size='5'> **Дерево решений**

# %%
params = {
    'criterion': ['gini',],
    'max_depth': [5, 10, 15,], # range(3, 15, 3)
    'min_samples_leaf': [10, 15, 20],
    'ccp_alpha': np.arange(0.1, 2, 0.5)
}

# %%
tree_classifier = DecisionTreeClassifier(random_state=42)

# %%
# Создаем объект GridSearchCV
grid_search = GridSearchCV(estimator=tree_classifier, param_grid=params, cv=5, n_jobs=-1, scoring='recall')

# %%
grid_search.fit(X_train_p, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': array([0.1, 0.6, 1.1, 1.6]),
#                          'criterion': ['gini'], 'max_depth': [5, 10, 15],
#                          'min_samples_leaf': [10, 15, 20]},
#              scoring='recall')

# %%
grid_search.best_params_
# Out:
# {'ccp_alpha': np.float64(0.1),
#  'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 10}

# %%
best_tree = grid_search.best_estimator_

# %%
calculate_metrics_and_plot_roc_comparison(
    model_log_reg,
    X_train_p,
    y_train,
    X_test_p,
    y_test,
    0.5)
# Out:
# {'train': {'precision': 0.9480012022843403,
#   'recall': 0.9339650577435594,
#   'roc_auc': np.float64(0.9572026826094071),
#   'fpr': array([0.00000000e+00, 0.00000000e+00, 1.04286161e-04, 1.04286161e-04,
#          2.08572322e-04, 2.08572322e-04, 4.17144645e-04, 4.17144645e-04,
#          5.21430806e-04, 5.21430806e-04, 6.25716967e-04, 6.25716967e-04,
#          9.77209945e-01, 9.77209945e-01, 9.77900552e-01, 9.77900552e-01,
#          9.78591160e-01, 9.78591160e-01, 9.79281768e-01, 9.79281768e-01,
#          9.79972376e-01, 9.79972376e-01, 9.80662983e-01, 9.80662983e-01,
#          9.81353591e-01, 9.81353591e-01, 9.82044199e-01, 9.82044199e-01,
#          9.82734807e-01, 9.82734807e-01, 9.83425414e-01, 9.83425414e-01,
#          9.84116022e-01, 9.84116022e-01, 9.84806630e-01, 9.84806630e-01,
#          9.85497238e-01, 9.85497238e-01, 9.86187845e-01, 9.86187845e-01,
#          9.86878453e-01, 9.86878453e-01, 9.87569061e-01, 9.87569061e-01,
#          9.88259669e-01, 9.88259669e-01, 9.88950276e-01, 9.88950276e-01,
#          9.89640884e-01, 9.89640884e-01, 9.90331492e-01, 9.90331492e-01,
#          9.91022099e-01, 9.91022099e-01, 9.91712707e-01, 9.91712707e-01,
#          9.92403315e-01, 9.92403315e-01, 9.93093923e-01, 9.93093923e-01,
#          9.93784530e-01, 9.93784530e-01, 9.94475138e-01, 9.94475138e-01,
#          9.95165746e-01, 9.95165746e-01, 9.95856354e-01, 9.95856354e-01,
#          9.96546961e-01, 9.96546961e-01, 9.97237569e-01, 9.97237569e-01,
#          9.97928177e-01, 9.97928177e-01, 9.98618785e-01, 9.98618785e-01,
#          9.99309392e-01, 9.99309392e-01, 1.00000000e+00, 1.00000000e+00]),
#   'threshold': 0.5}}

# %%
pred_train = best_tree.predict_proba(X_train_p)
pred_test = best_tree.predict_proba(X_test_p)

# %%
pd.DataFrame(
    {"feature": X_train_p.columns, "importance": best_tree.feature_importances_}
).sort_values(by="importance", ascending=False).reset_index(drop=True)
# Out:
#                           feature  importance
# 0  cat__drained_after_socializing         1.0
# 1                 cat__stage_fear         0.0
# 2           num__time_spent_alone         0.0
# 3    num__social_event_attendance         0.0
# 4              num__going_outside         0.0
# 5        num__friends_circle_size         0.0
# 6             num__post_frequency         0.0

# %%
# второй способ отрисовать деревья с помощью plot_tree
plt.figure(figsize=(10, 10))
plot_tree(best_tree, feature_names=X_train_p.columns, filled=True, rounded=True,  fontsize=10)
plt.show()
plt.savefig('tree.png')

# %% [markdown]
# ## <font color='blue'> **Random Forest**

# %%
# итоговый пайплайн: подготовка данных и модель RandomForestClassifier
rf_cl = Pipeline(
   [
       ('preprocessor', data_preprocessor),
       ('rf_models', RandomForestClassifier(random_state = 1234))

   ]
)

# %%
rf_cl.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('enc',
#                                                                    TargetEncoder(cols=['stage_fear',
#                                                                                        'drained_after_socializing'])),
#                                                                   ('imputer',
#                                                                    SimpleImputer(strategy='most_frequent'))]),
#                                                   ['stage_fear',
#                                                    'drained_after_socializing']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['time_spent_alone',
#                                                    'social_event_attendance',
#                                                    'going_outside',
#                                                    'friends_circle_size',
#                                                    'post_frequency'])])),
#                 ('rf_models', RandomForestClassifier(random_state=1234))])

# %%
pred_train = rf_cl.predict_proba(X_train)

# %%
pred_test = rf_cl.predict_proba(X_test)

# %%
rf_cl.steps
# Out:
# [('preprocessor',
#   ColumnTransformer(remainder='passthrough',
#                     transformers=[('cat',
#                                    Pipeline(steps=[('enc',
#                                                     TargetEncoder(cols=['stage_fear',
#                                                                         'drained_after_socializing'])),
#                                                    ('imputer',
#                                                     SimpleImputer(strategy='most_frequent'))]),
#                                    ['stage_fear', 'drained_after_socializing']),
#                                   ('num',
#                                    Pipeline(steps=[('scaler', StandardScaler()),
#                                                    ('imputer', SimpleImputer())]),
#                                    ['time_spent_alone', 'social_event_attendance',
#                                     'going_outside', 'friends_circle_size',
#                                     'post_frequency'])])),
#  ('rf_models', RandomForestClassifier(random_state=1234))]

# %%
param_grid = {
    'rf_models__n_estimators': [100, 200],  # Количество деревьев в лесу
    'rf_models__criterion': ['gini', ],      # Функция для измерения качества разделения: индекс Джини или энтропия
    'rf_models__max_depth': [5, 7, 10],        # Максимальная глубина дерева: ограничение глубины для избежания переобучения
    # 'rf_models__min_samples_split': [5, 10],       # Минимальное количество выборок, необходимых для разделения внутреннего узла
    'rf_models__min_samples_leaf': [7, 10],         # Минимальное количество выборок, необходимых для узла листа
    'rf_models__max_features': ['log2'], # Количество признаков для поиска наилучшего разделения
                                                       # 'sqrt' - корень из общего кол-ва признаков, 'log2' - логарифм по основанию 2 от общего кол-ва признаков, None - все признаки
}

# %%
grid_search = GridSearchCV(rf_cl, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.3s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.3s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.3s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.3s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.3s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=5, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   1.0s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.4s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.7s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=7, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.8s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=100; total time=   0.6s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   1.0s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=7, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=100; total time=   0.5s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   0.9s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   1.0s
# [CV] END rf_models__criterion=gini, rf_models__max_depth=10, rf_models__max_features=log2, rf_models__min_samples_leaf=10, rf_models__n_estimators=200; total time=   1.2s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          Pipeline(steps=[('enc',
#                                                                                           TargetEncoder(cols=['stage_fear',
#                                                                                                               'drained_after_socializing'])),
#                                                                                          ('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent'))]),
#                                                                          ['stage_fear',
#                                                                           'drained_after_socializing']),
#                                                                         ('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardS...
#                                                                           'social_event_attendance',
#                                                                           'going_outside',
#                                                                           'friends_circle_size',
#                                                                           'post_frequency'])])),
#                                        ('rf_models',
#                                         RandomForestClassifier(random_state=1234))]),
#              param_grid={'rf_models__criterion': ['gini'],
#                          'rf_models__max_depth': [5, 7, 10],
#                          'rf_models__max_features': ['log2'],
#                          'rf_models__min_samples_leaf': [7, 10],
#                          'rf_models__n_estimators': [100, 200]},
#              scoring='accuracy', verbose=2)

# %%
# Получаем лучшее значение параметров, найденных в процессе кросс-валидации
print("Лучшие параметры:", grid_search.best_params_)
# Out:
# Лучшие параметры: {'rf_models__criterion': 'gini', 'rf_models__max_depth': 7, 'rf_models__max_features': 'log2', 'rf_models__min_samples_leaf': 7, 'rf_models__n_estimators': 100}

# %%
pred_train = grid_search.best_estimator_.predict_proba(X_train)

# %%
best_rf_model = grid_search.best_estimator_

# %%
pred_test = best_rf_model.predict_proba(X_test)

# %%
res_rf = calculate_metrics_and_plot_roc_comparison(
    best_rf_model,
    X_train,
    y_train,
    X_test,
    y_test,
    0.5)

# %% [markdown]
# # <font color='blue'> **Интерпретация лучшей модели**

# %%
best_rf_model.steps[1][1]
# Out:
# RandomForestClassifier(max_depth=7, max_features='log2', min_samples_leaf=7,
#                        random_state=1234)

# %%
# %%time
explainer_tree = shap.Explainer(best_rf_model.steps[1][1].predict, X_test_p)
shap_values_tree = explainer_tree(X_test_p)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-212-3183185756.py in <cell line: 0>()
#       1 explainer_tree = shap.Explainer(best_rf_model.steps[1][1].predict, X_test_p)
# ----> 2 shap_values_tree = explainer_tree(X_test_p)
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_exact.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, interactions, silent, *args)
#      82         # we entirely rely on the general call implementation, we override just to remove **kwargs
#      83         # from the function signature
# ---> 84         return super().__call__(
#      85             *args,
#      86             max_evals=max_evals,
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     364             feature_names = [[] for _ in range(len(args))]
#     365         for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__ + " explainer", silent):
# --> 366             row_result = self.explain_row(
#     367                 *row_args,
#     368                 max_evals=max_evals,
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_exact.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, interactions, silent, *row_args)
#     184             if inds is None:
#     185                 inds = np.arange(len(fm))
# --> 186             main_effect_values = fm.main_effects(inds)
#     187             if interactions is True or interactions == 2:
#     188                 for i in range(len(fm)):
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in main_effects(self, inds, batch_size)
#     268
#     269         # compute the main effects for the given indexes
# --> 270         outputs = self(masks, batch_size=batch_size)
#     271         main_effects = outputs[1:] - outputs[0]
#     272
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in __call__(self, masks, zero_index, batch_size)
#      55         if len(masks.shape) == 1:
#      56             if getattr(self.masker, "supports_delta_masking", False):
# ---> 57                 return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      58
#      59             # we need to convert from delta masking to a full masking call because we were given a delta masking
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in _delta_masking_call(self, masks, zero_index, batch_size)
#     207
#     208         # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 209         outputs = self.model(*subset_masked_inputs)
#     210         _assert_output_input_match(subset_masked_inputs, outputs)
#     211
#
# /usr/local/lib/python3.11/dist-packages/shap/models/_model.py in __call__(self, *args)
#      21
#      22     def __call__(self, *args):
# ---> 23         out = self.inner_model(*args)
#      24         is_tensor = safe_isinstance(out, "torch.Tensor")
#      25         out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     902             The predicted classes.
#     903         """
# --> 904         proba = self.predict_proba(X)
#     905
#     906         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     955         ]
#     956         lock = threading.Lock()
# --> 957         Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     958             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
#     959             for e in self.estimators_
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1984             output = self._get_sequential_output(iterable)
#    1985             next(output)
# -> 1986             return output if self.return_generator else list(output)
#    1987
#    1988         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1912                 self.n_dispatched_batches += 1
#    1913                 self.n_dispatched_tasks += 1
# -> 1914                 res = func(*args, **kwargs)
#    1915                 self.n_completed_tasks += 1
#    1916                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in _accumulate_prediction(predict, X, out, lock)
#     729     complains that it cannot pickle it when placed there.
#     730     """
# --> 731     prediction = predict(X, check_input=False)
#     732     with lock:
#     733         if len(out) == 1:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#    1056         check_is_fitted(self)
#    1057         X = self._validate_X_predict(X, check_input)
# -> 1058         proba = self.tree_.predict(X)
#    1059
#    1060         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
i = 1
shap.plots.waterfall(shap_values_tree[i], max_display=14)

# %%
shap.plots.beeswarm(shap_values_tree)

# %% [markdown]
# # <font color='blue'> **Сохранение модели**

# %%
import pickle

# Сохранение пайплайна в файл
with open('pipeline_best_model.pkl', 'wb') as f:
    pickle.dump(best_rf_model, f)

print("Pipeline сохранен в файл 'pipeline_best_model.pkl'.")
# Out:
# Pipeline сохранен в файл 'pipeline_best_model.pkl'.

# %% [markdown]
# # <font color='blue'> **Инференс модели**

# %%
# Загрузка пайплайна из файла
with open('pipeline_best_model.pkl', 'rb') as f:
    loaded_pipeline = pickle.load(f)

print("Pipeline загружен.")
# Out:
# Pipeline загружен.

# %%
loaded_pipeline.steps[1][1]
# .get_feature_names_out()
# Out:
# RandomForestClassifier(max_depth=5, max_features='log2', min_samples_leaf=10,
#                        random_state=1234)

# %%
df_test['pred'] = loaded_pipeline.predict(df_test)

# %%
# dict_personality = {'Extrovert':0, 'Introvert':1}
dict_personality_rev = {0:'Extrovert', 1:'Introvert'}

# %%
df_test['Personality'] = df_test['pred'].map(dict_personality_rev)

# %%
df_test[['id', 'Personality']].to_csv('submission.csv', index=False)

# %%
# !kaggle competitions submit -c playground-series-s5e7 -f submission.csv -m "1 commit"
# Out:
# 100% 96.5k/96.5k [00:00<00:00, 252kB/s]
# Successfully submitted to Predict the Introverts from the Extroverts
